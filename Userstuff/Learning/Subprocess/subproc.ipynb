# %%
import subprocess as sp

result = sp.run(["ls", "-l"], capture_output=True)
print(result.args)
print(result.returncode)
print(result.stderr)
print(result.stdout)
# Out:
# ['ls', '-l']
# 0
# b''
# b'total 4\n-rw-rw-r--    1 Lenovo   Lenovo        1401 Mar 20 20:55 subproc.ipynb\n'
